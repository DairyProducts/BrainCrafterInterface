# %% [markdown]
# # Data Visualization Testbench
# I (Derek) am using this notebook just to plot/mess around with the data that we got.

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
print(os.getcwd())

# %%
# Location and whatnot
DATA_FOLDER = "data/"
DATA_SESSION = "2-18/ses-01/"

# %%
# Load numpy arrays
aux = np.load(DATA_FOLDER + DATA_SESSION + "aux_2-per-class_run-1.npy")
aux_trials = np.load(DATA_FOLDER + DATA_SESSION + "aux-trials_2-per-class_run-1.npy")
eeg = np.load(DATA_FOLDER + DATA_SESSION + "eeg_2-per-class_run-1.npy")
eeg_trials = np.load(DATA_FOLDER + DATA_SESSION + "eeg-trials_2-per-class_run-1.npy")

# %%
print(aux.shape)
print(aux_trials.shape)
print(eeg.shape)
print(eeg_trials.shape)

# %%
# Plot some eeg data

trial = 60

for i in range(eeg_trials.shape[1]):
    plt.figure(figsize=(12, 2))
    plt.plot(eeg_trials[trial, i, :])
    plt.title(f"channel {i}, trial {trial}")
    plt.show()
